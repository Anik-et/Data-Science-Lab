# %%
import sys
from pathlib import Path
for path in sys.path:
    print(path)
# Out:
# p:\Data Science Learning\8 Live\Data-Science-Lab\projects\01_credit_card_fraud_detection\notebooks
# c:\Users\anike\anaconda3\envs\DeepLearning\python311.zip
# c:\Users\anike\anaconda3\envs\DeepLearning\DLLs
# c:\Users\anike\anaconda3\envs\DeepLearning\Lib
# c:\Users\anike\anaconda3\envs\DeepLearning
#
# c:\Users\anike\anaconda3\envs\DeepLearning\Lib\site-packages
# c:\Users\anike\anaconda3\envs\DeepLearning\Lib\site-packages\win32
# c:\Users\anike\anaconda3\envs\DeepLearning\Lib\site-packages\win32\lib
# c:\Users\anike\anaconda3\envs\DeepLearning\Lib\site-packages\Pythonwin

# %%
print(type(sys.path))
print(type(sys.path[0]))
# Out:
# <class 'list'>
# <class 'str'>

# %%
path.cwd()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 path.cwd()
#
# AttributeError: 'str' object has no attribute 'cwd'

# %%
type(path)
# Out:
# str

# %%
from pathlib import Path
Path.cwd()
# Out:
# WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/notebooks')

# %%
my_path = Path.cwd()
type(my_path)
# Out:
# pathlib.WindowsPath

# %%
project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
sys.path[-1]
# Out:
# 'p:\\Data Science Learning\\8 Live\\Data-Science-Lab\\projects\\01_credit_card_fraud_detection'

# %%
project_root = Path.cwd().parent

print(project_root)
# Out:
# p:\Data Science Learning\8 Live\Data-Science-Lab\projects\01_credit_card_fraud_detection

# %%
list((project_root / "src").iterdir())
# Out:
# [WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/src/data'),
#  WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/src/features'),
#  WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/src/models'),
#  WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/src/utils'),
#  WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/src/visualization'),
#  WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/src/__init__.py'),
#  WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/src/__pycache__')]

# %%
list((project_root / "src" / "utils").iterdir())
# Out:
# [WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/src/utils/config.py'),
#  WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/src/utils/logger.py'),
#  WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/src/utils/__init__.py'),
#  WindowsPath('p:/Data Science Learning/8 Live/Data-Science-Lab/projects/01_credit_card_fraud_detection/src/utils/__pycache__')]

# %%
from pathlib import Path

project_root = Path.cwd().parent

(project_root / "src" / "utils" / "__init__.py").exists()
# Out:
# True

# %%
(project_root / "src" / "utils" / "config.py").exists()
# Out:
# True

# %%
import sys

for i, p in enumerate(sys.path):
    print(i, p)
# Out:
# 0 p:\Data Science Learning\8 Live\Data-Science-Lab\projects\01_credit_card_fraud_detection\notebooks
# 1 c:\Users\anike\anaconda3\envs\DeepLearning\python311.zip
# 2 c:\Users\anike\anaconda3\envs\DeepLearning\DLLs
# 3 c:\Users\anike\anaconda3\envs\DeepLearning\Lib
# 4 c:\Users\anike\anaconda3\envs\DeepLearning
# 5
# 6 c:\Users\anike\anaconda3\envs\DeepLearning\Lib\site-packages
# 7 c:\Users\anike\anaconda3\envs\DeepLearning\Lib\site-packages\win32
# 8 c:\Users\anike\anaconda3\envs\DeepLearning\Lib\site-packages\win32\lib
# 9 c:\Users\anike\anaconda3\envs\DeepLearning\Lib\site-packages\Pythonwin
# 10 p:\Data Science Learning\8 Live\Data-Science-Lab\projects\01_credit_card_fraud_detection

# %%
import importlib.util

spec = importlib.util.find_spec("src")
print(spec)
# Out:
# ModuleSpec(name='src', loader=<_frozen_importlib_external.SourceFileLoader object at 0x000001CBD153F410>, origin='p:\\Data Science Learning\\8 Live\\Data-Science-Lab\\projects\\01_credit_card_fraud_detection\\src\\__init__.py', submodule_search_locations=['p:\\Data Science Learning\\8 Live\\Data-Science-Lab\\projects\\01_credit_card_fraud_detection\\src'])

# %%
spec = importlib.util.find_spec("src.utils")
print(spec)
# Out:
# ModuleSpec(name='src.utils', loader=<_frozen_importlib_external.SourceFileLoader object at 0x000001CBD152C990>, origin='p:\\Data Science Learning\\8 Live\\Data-Science-Lab\\projects\\01_credit_card_fraud_detection\\src\\utils\\__init__.py', submodule_search_locations=['p:\\Data Science Learning\\8 Live\\Data-Science-Lab\\projects\\01_credit_card_fraud_detection\\src\\utils'])

# %%
spec = importlib.util.find_spec("src.utils.config")
print(spec)
# Out:
# ModuleSpec(name='src.utils.config', loader=<_frozen_importlib_external.SourceFileLoader object at 0x000001CBD150CFD0>, origin='p:\\Data Science Learning\\8 Live\\Data-Science-Lab\\projects\\01_credit_card_fraud_detection\\src\\utils\\config.py')

# %%
import sys

print(sys.executable)
# Out:
# c:\Users\anike\anaconda3\envs\DeepLearning\python.exe

# %%
from src.utils.config import load_config

config = load_config()

config
# Out:
# {'project': {'name': 'Credit Card Fraud Detection', 'version': 0.1},
#  'dataset': {'source': 'kaggle',
#   'owner': 'mlg-ulb',
#   'name': 'creditcardfraud',
#   'filename': 'creditcard.csv'},
#  'paths': {'raw_data': 'data/raw',
#   'processed_data': 'data/processed',
#   'external_data': 'data/external'},
#  'model': {'random_state': 42, 'test_size': 0.2},
#  'download': {'force_download': False}}

# %%
from pathlib import Path
from src.data.download_data import _create_data_directory

test_path = Path("data/raw")

_create_data_directory(test_path)

print(test_path.exists())
# Out:
# True

# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
from src.utils.config import load_config

config = load_config()

config
# Out:
# {'project': {'name': 'Credit Card Fraud Detection', 'version': 0.1},
#  'dataset': {'source': 'kaggle',
#   'owner': 'mlg-ulb',
#   'name': 'creditcardfraud',
#   'filename': 'creditcard.csv'},
#  'paths': {'raw_data': 'data/raw',
#   'processed_data': 'data/processed',
#   'external_data': 'data/external'},
#  'model': {'random_state': 42, 'test_size': 0.2},
#  'download': {'force_download': False}}

# %%
from src.data.download_data import _create_data_directory

test_path = Path("data/raw")

_create_data_directory(test_path)

print(test_path.exists())
# Out:
# True

# %%
from src.data.download_data import _dataset_exists

_dataset_exists(Path("data/raw/creditcard.csv"))
# Out:
# False

# %%
from src.data.download_data import download_dataset

dataset_path = download_dataset()

dataset_path
# Out:
# ...
# Dataset downloaded successfully.
# WindowsPath('data/raw/creditcard.csv')

# %%
import pandas as pd

df = pd.read_csv(dataset_path)

df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...
